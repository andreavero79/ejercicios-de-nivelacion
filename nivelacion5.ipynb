# %% [markdown]
# <a href="https://colab.research.google.com/github/andreavero79/ejercicios-de-nivelacion/blob/main/nivelacion5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("********************")
print("*sucesión fibonacci*")
print("********************")
num_uno, num_dos = 0,1
while num_dos<=1597:
   print(num_uno,num_dos, end="")
   num_uno =num_uno + num_dos
   nun_dos =num_uno + num_dos
# Out:
# ********************
# *sucesión fibonacci*
# ********************
# ...
